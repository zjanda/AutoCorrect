# %%
import re
import nltk
import dill as pickle
import numpy as np
from icecream import ic
from nltk.corpus import words
from nltk.metrics.distance import edit_distance
from nltk.lm.preprocessing import pad_both_ends
from tqdm import tqdm

# %%
with open('text.txt', 'r') as file:
    text = file.read()

text = text.lower().strip()
text = re.sub(r'[^\w\s]', ' ', text)

tokenize = nltk.tokenize.word_tokenize
stem = nltk.stem.porter.PorterStemmer().stem
lemmatize = nltk.stem.WordNetLemmatizer().lemmatize

# %%
with open('word-lists/words.txt', 'r') as file:
    words_list = file.read().split()
with open('word-lists/english3.txt', 'r') as file:
    english_list = file.read().split()

correct_words = words.words()
in_corr_words = {}

for word in tqdm(correct_words):
    in_corr_words[word] = 1

print('Adding words_list to correct words...')
for word in tqdm(words_list):
    try:
        in_corr_words[word]
    except KeyError:
        in_corr_words[word] = 1
        correct_words.append(word)

print('Adding english_list to correct words...')
for word in tqdm(english_list):
    try:
        in_corr_words[word]
    except KeyError:
        in_corr_words[word] = 1
        correct_words.append(word)

print('Tokenizing correct words...')
correct_tokens = [lemmatize(stem(word)) for word in tqdm(correct_words)]
tokens_dict = {}
print('Creating tokens dictionary...')
for t in tqdm(correct_tokens):
    tokens_dict[t] = 1
# Out:
# 100%|██████████| 236736/236736 [00:00<00:00, 1849878.72it/s]
# Adding words_list to correct words...
# 100%|██████████| 69903/69903 [00:00<00:00, 1426799.39it/s]
# Adding english_list to correct words...
# 100%|██████████| 194432/194432 [00:00<00:00, 1157272.68it/s]
# Tokenizing correct words...
# 100%|██████████| 355932/355932 [00:08<00:00, 44440.55it/s]
# Creating tokens dictionary...
# 100%|██████████| 355932/355932 [00:00<00:00, 1858116.54it/s]

# %%
original_tokens = list(pad_both_ends(tokenize(text), 3))
tokens = [lemmatize(stem(token)) for token in original_tokens]

possible_words = {}
tokens = list(pad_both_ends(tokens, 1))
print(tokens[:3], tokens[-3:])
# Out:
# ['<s>', '<s>', '1'] ['pigment', '</s>', '</s>']

# %%
with open('model.pk', 'rb') as fin:
    model = pickle.load(fin)

# %%
for token_index, token in tqdm(enumerate(tokens)):
    if '<s>' == token or token == '</s>':
        continue
    try:
        int(token)
        continue
    except ValueError:
        try:
            tokens_dict[token]
            continue
        except KeyError:
            pass
        t = []
        error = 0
        min = 0
        word = original_tokens[token_index]
        for i, w in enumerate(correct_tokens):
            error = edit_distance(token, w)
            t.append(error)
            if error < t[min]:
                ic(error, token, w)
                min = i
                possible_words[word] = [correct_words[i]]
            elif error == t[min]:
                try:
                    possible_words[word].append(correct_words[i])
                except KeyError:
                    possible_words[word] = [correct_words[i]]

        prev_words = original_tokens[token_index - 2:token_index]
        for possible_word in possible_words[word]:
            ic(prev_words, possible_word)
            ic(model.score(possible_word, prev_words))
            ic(model.score(possible_word, prev_words[-1]))
            ic(model.score(possible_word))

        ic(possible_words[word])
        guess = possible_words[word][np.argmax([model.score(possible_word) for possible_word in possible_words[word]])]
        print('Guess:', *prev_words, guess)

    print('Number of misspelled words:', len(possible_words.keys()))
    print('Spelling Accuracy:', '%.4f' % (1 - len(possible_words.keys()) / token_index))
# Out:
# 0it [00:00, ?it/s]ic| error: 8, token: 'extreemli', w: 'aal'
# ic| error: 7, token: 'extreemli', w: 'aardwolf'
# ic| error: 6, token: 'extreemli', w: 'abasedli'
# ic| error: 5, token: 'extreemli', w: 'alarmedli'
# ic| error: 4, token: 'extreemli', w: 'beseemli'
# ic| error: 3, token: 'extreemli', w: 'expressli'
# ic| error: 2, token: 'extreemli', w: 'extremi'
# ic| prev_words: ['and', 'talks'], possible_word: 'extremis'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| possible_words[word]: ['extremis']
# 18it [00:20,  1.14s/it]ic| error: 4, token: 'nergi', w: 'aalii'
# ic| error: 3, token: 'nergi', w: 'adagi'
# ic| error: 2,
# Guess: and talks extremis
# Number of misspelled words: 1
# Spelling Accuracy: 0.9412
#  token: 'nergi', w: 'aegi'
# ic| error: 1, token: 'nergi', w: 'anergi'
# ic| prev_words: ['3', 'e'], possible_word: 'anergy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['3', 'e'], possible_word: 'bergy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['3', 'e'], possible_word: 'energy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.783687464660692e-05
# ic| prev_words: ['3', 'e'], possible_word: 'Nereis'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['3', 'e'], possible_word: 'Neri'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['3', 'e'], possible_word: 'nerviness'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['3', 'e'], possible_word: 'nervy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['3', 'e'], possible_word: 'vergi'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['3', 'e'], possible_word: 'energies'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['3', 'e'], possible_word: 'nerdy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| possible_words[word]: ['anergy',
#                            'bergy',
#                            'energy',
#                            'Nereis',
#                            'Neri',
#                            'nerviness',
#                            'nervy',
#                            'vergi',
#                            'energies',
#                            'nerdy']
# 104it [00:32,  3.76it/s]ic| error: 3, token: 'howi', w: 'aani'
# Guess: 3 e energy
# Number of misspelled words: 2
# Spelling Accuracy: 0.9806
# ic| error: 2, token: 'howi', w: 'blowi'
# ic| error: 1, token: 'howi', w: 'bowi'
# ic| prev_words: ['our', 'topic'], possible_word: 'bowie'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'bowieful'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'cowy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'dowie'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'dowiness'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'hoi'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'holiness'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.3080374740845075e-05
# ic| prev_words: ['our', 'topic'], possible_word: 'holy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 4.5186749104737534e-05
# ic| prev_words: ['our', 'topic'], possible_word: 'hominess'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'homy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'honied'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'Hopi'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'hopi'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'hory'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'hoti'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'how'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.001386519722529578
# ic| prev_words: ['our', 'topic'], possible_word: 'howdie'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howdy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.783687464660692e-06
# ic| prev_words: ['our', 'topic'], possible_word: 'howe'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howk'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howl'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.5458624693725998e-05
# ic| prev_words: ['our', 'topic'], possible_word: 'howling'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 3.567374929321384e-05
# ic| prev_words: ['our', 'topic'], possible_word: 'lowy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'mowie'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'nowy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'rowiness'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'rowy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'showiness'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'showy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'towy'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'yowie'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'zowie'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'how'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.001386519722529578
# ic| prev_words: ['our', 'topic'], possible_word: 'holies'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'honi'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'hoki'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'hoky'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'holi'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['our', 'topic'], possible_word: 'holinesses'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'hopis'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howdies'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howes'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howf'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howfs'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howked'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howking'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howks'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howled'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 2.3187937040589e-05
# ic| prev_words: ['our', 'topic'], possible_word: 'howlings'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'howls'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 3.567374929321384e-06
# ic| prev_words: ['our', 'topic'], possible_word: 'hows'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'powys'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['our', 'topic'], possible_word: 'yowies'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| possible_words[word]: ['bowie',
#                            'bowieful',
#                            'cowy',
#                            'dowie',
#                            'dowiness',
#                            'hoi',
#                            'holiness',
#                            'holy',
#                            'hominess',
#                            'homy',
#                            'honied',
#                            'Hopi',
#                            'hopi',
#                            'hory',
#                            'hoti',
#                            'how',
#                            'howdie',
#                            'howdy',
#                            'howe',
#                            'howk',
#                            'howl',
#                            'howling',
#                            'lowy',
#                            'mowie',
#                            'nowy',
#                            'rowiness',
#                            'rowy',
#                            'showiness',
#                            'showy',
#                            'towy',
#                            'yowie',
#                            'zowie',
#                            'how',
#                            'holies',
#                            'honi',
#                            'hoki',
#                            'hoky',
#                            'holi',
#                            'holinesses',
#                            'hopis',
#                            'howdies',
#                            'howes',
#                            'howf',
#                            'howfs',
#                            'howked',
#                            'howking',
#                            'howks',
#                            'howled',
#                            'howlings',
#                            'howls',
#                            'hows',
#                            'powys',
#                            'yowies']
# 115it [00:46,  2.46it/s]
# Guess: our topic how
# Number of misspelled words: 3
# Spelling Accuracy: 0.9737
# ic| error: 1, token: 'dj', w: 'd'
# ic| prev_words: ['on', 'this'], possible_word: 'D'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'd'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0017468245903910378
# ic| prev_words: ['on', 'this'], possible_word: 'da'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.0107562299743922e-05
# ic| prev_words: ['on', 'this'], possible_word: 'das'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['on', 'this'], possible_word: 'de'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 7.729312346862999e-06
# ic| prev_words: ['on', 'this'], possible_word: 'di'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['on', 'this'], possible_word: 'dis'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 2.3782499528809226e-06
# ic| prev_words: ['on', 'this'], possible_word: 'do'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0022230691434554427
# ic| prev_words: ['on', 'this'], possible_word: 'doing'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0002770661195106275
# ic| prev_words: ['on', 'this'], possible_word: 'doings'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 2.3782499528809226e-06
# ic| prev_words: ['on', 'this'], possible_word: 'dos'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'J'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'j'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 3.567374929321384e-06
# ic| prev_words: ['on', 'this'], possible_word: 'do'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0022230691434554427
# ic| prev_words: ['on', 'this'], possible_word: 'adj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'bj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'db'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['on', 'this'], possible_word: 'dc'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['on', 'this'], possible_word: 'dd'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'des'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 2.9728124411011534e-06
# ic| prev_words: ['on', 'this'], possible_word: 'df'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'dg'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'dr'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.9620562111267613e-05
# ic| prev_words: ['on', 'this'], possible_word: 'dt'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'du'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'dyed'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.1891249764404614e-05
# ic| prev_words: ['on', 'this'], possible_word: 'ej'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'fj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'gj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'ij'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'kj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'lj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'mj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'nj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'pj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['on', 'this'], possible_word: 'rj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'sj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'tj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'wj'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'dieses'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'dl'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['on', 'this'], possible_word: 'dyings'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| possible_words[word]: ['D',
#                            'd',
#                            'da',
#                            'das',
#                            'de',
#                            'di',
#                            'dis',
#                            'do',
#                            'doing',
#                            'doings',
#                            'dos',
#                            'J',
#                            'j',
#                            'do',
#                            'adj',
#                            'bj',
#                            'db',
#                            'dc',
#                            'dd',
#                            'des',
#                            'df',
#                            'dg',
#                            'dr',
#                            'dt',
#                            'du',
#                            'dyed',
#                            'ej',
#                            'fj',
#                            'gj',
#                            'ij',
#                            'kj',
#                            'lj',
#                            'mj',
#                            'nj',
#                            'pj',
#                            'rj',
#                            'sj',
#                            'tj',
#                            'wj',
#                            'dieses',
#                            'dl',
#                            'dyings']
# 129it [00:56,  2.16it/s]ic| error: 4, token: 'thier', w: 'abbey'
# ic| error: 3, token: 'thier', w: 'abiet'
# ic| error: 2, token: 'thier', w: 'acier'
# Guess: on this do
# Number of misspelled words: 4
# Spelling Accuracy: 0.9688
# ic| error: 1, token: 'thier', w: 'shier'
# ic| prev_words: ['been', 'losing'], possible_word: 'shier'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'theer'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'thief'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.605318718194623e-05
# ic| prev_words: ['been', 'losing'], possible_word: 'thieve'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'thieving'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.783687464660692e-06
# ic| prev_words: ['been', 'losing'], possible_word: 'thir'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['been', 'losing'], possible_word: 'tier'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'tiered'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 5.945624882202307e-07
# ic| prev_words: ['been', 'losing'], possible_word: 'trier'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'thieves'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.9620562111267613e-05
# ic| prev_words: ['been', 'losing'], possible_word: 'shiers'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'thiefs'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'thieved'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'thievings'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'tiering'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'tiers'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 1.783687464660692e-06
# ic| prev_words: ['been', 'losing'], possible_word: 'triers'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'twier'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| prev_words: ['been', 'losing'], possible_word: 'twiers'
# ic| model.score(possible_word, prev_words): 0
# ic| model.score(possible_word, prev_words[-1]): 0
# ic| model.score(possible_word): 0.0
# ic| possible_words[word]: ['shier',
#                            'theer',
#                            'thief',
#                            'thieve',
#                            'thieving',
#                            'thir',
#                            'tier',
#                            'tiered',
#                            'trier',
#                            'thieves',
#                            'shiers',
#                            'thiefs',
#                            'thieved',
#                            'thievings',
#                            'tiering',
#                            'tiers',
#                            'triers',
#                            'twier',
#                            'twiers']
# 159it [01:08,  2.31it/s]
# Guess: been losing thieves
# Number of misspelled words: 5
# Spelling Accuracy: 0.9624

# %%
# Out:
# True
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 print('children' in words_list)
# ----> 2 tokens_dict['children']
#
# KeyError: 'children'

# %%
lemmatize(stem('children'))
